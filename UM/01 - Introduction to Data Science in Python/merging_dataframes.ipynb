# %%
import pandas as pd

staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                        {'Name': 'Sally', 'Role': 'Course liasion'},
                        {'Name': 'James', 'Role': 'Grader'}])
staff_df = staff_df.set_index('Name')

student_df = pd.DataFrame([{'Name': 'James', 'School': 'Businnes'},
                        {'Name': 'Mike', 'School': 'Law'},
                        {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')

print(staff_df.head())
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#             School
# Name
# James     Businnes
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Businnes
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
pd.merge(staff_df, student_df, how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Businnes

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Businnes

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Businnes
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

pd.merge(staff_df, student_df, how='right', on='Name')
# Out:
#     Name            Role       School
# 0  James          Grader     Businnes
# 1   Mike             NaN          Law
# 2  Sally  Course liasion  Engineering

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                        {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                        {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])

student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                        {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                        {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])

pd.merge(staff_df, student_df, how='left', on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                        {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                        {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])

student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Businnes'},
                        {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                        {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])

pd.merge(staff_df, student_df, how='inner', on=['First Name', 'Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %%
# %%capture
df_2011_1 = pd.read_csv('csv/MERGED2011_PP_1.csv', error_bad_lines=False)
df_2011_2 = pd.read_csv('csv/MERGED2011_PP_2.csv', error_bad_lines=False)
df_2012_1 = pd.read_csv('csv/MERGED2012_PP_1.csv', error_bad_lines=False)
df_2012_2 = pd.read_csv('csv/MERGED2012_PP_2.csv', error_bad_lines=False)
df_2013 = pd.read_csv('csv/MERGED2013_PP.csv', error_bad_lines=False)

# %%
df_2011_1.head(3)
# Out:
#    UNITID    OPEID  opeid6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
#
#   STABBR         ZIP  AccredAgency  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
#
#    PELL_RPY_3YR_RT_SUPP  NOPELL_RPY_3YR_RT_SUPP  FEMALE_RPY_3YR_RT_SUPP  \
# 0                   0.5          0.504513540622          0.420550847458
# 1        0.844773790952          0.790354330709          0.757345971564
# 2        0.636363636364          0.487012987013          0.609523809524
#
#    MALE_RPY_3YR_RT_SUPP  FIRSTGEN_RPY_3YR_RT_SUPP  \
# 0        0.470229007634            0.455089820359
# ...

# %%
df_2011_2.head(3)
# Out:
#    UNITID    OPEID  opeid6                                    INSTNM    CITY  \
# 0  222992  1201500   12015         Austin Community College District  Austin
# 1  223001   354400    3544  Austin Presbyterian Theological Seminary  Austin
# 2  223056  1226800   12268        Baldwin Beauty School-South Austin  Austin
#
#   STABBR         ZIP  AccredAgency  INSTURL  NPCURL  ...  \
# 0     TX       78752           NaN      NaN     NaN  ...
# 1     TX  78705-5797           NaN      NaN     NaN  ...
# 2     TX  78704-4785           NaN      NaN     NaN  ...
#
#    PELL_RPY_3YR_RT_SUPP  NOPELL_RPY_3YR_RT_SUPP  FEMALE_RPY_3YR_RT_SUPP  \
# 0        0.696419566314          0.601592356688          0.556166895919
# 1     PrivacySuppressed       PrivacySuppressed       PrivacySuppressed
# 2                   NaN                     NaN                     NaN
#
#    MALE_RPY_3YR_RT_SUPP  FIRSTGEN_RPY_3YR_RT_SUPP  \
# 0        0.567779960707             0.61186696901
# ...

# %%
df_2012_1.head(3)
# Out:
#    UNITID    OPEID  opeid6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
#
#   STABBR         ZIP  AccredAgency  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
#
#    PELL_RPY_3YR_RT_SUPP  NOPELL_RPY_3YR_RT_SUPP  FEMALE_RPY_3YR_RT_SUPP  \
# 0        0.435294117647          0.469199178645           0.40465631929
# 1        0.814925373134           0.78531598513          0.749778956676
# 2        0.605263157895          0.465277777778          0.544642857143
#
#    MALE_RPY_3YR_RT_SUPP  FIRSTGEN_RPY_3YR_RT_SUPP  \
# 0        0.458398744113            0.418864097363
# ...

# %%
df_2012_2.head(3)
# Out:
#    UNITID    OPEID  opeid6                                             INSTNM  \
# 0  225201  1050900   10509  Hallmark College of Technology/Hallmark Colleg...
# 1  225247   357100    3571                          Hardin-Simmons University
# 2  225308   357200    3572                   Trinity Valley Community College
#
#           CITY STABBR         ZIP  AccredAgency  INSTURL  NPCURL  ...  \
# 0  San Antonio     TX  78230-1736           NaN      NaN     NaN  ...
# 1      Abilene     TX  79698-0001           NaN      NaN     NaN  ...
# 2       Athens     TX       75751           NaN      NaN     NaN  ...
#
#    PELL_RPY_3YR_RT_SUPP  NOPELL_RPY_3YR_RT_SUPP  FEMALE_RPY_3YR_RT_SUPP  \
# 0        0.632768361582          0.488448844884          0.482051282051
# 1        0.884020618557          0.832985386221          0.759590792839
# 2        0.618604651163          0.449487554905          0.371601208459
#
#    MALE_RPY_3YR_RT_SUPP  FIRSTGEN_RPY_3YR_RT_SUPP  \
# ...

# %%
df_2013.head(3)
# Out:
#    UNITID    OPEID  opeid6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
#
#   STABBR         ZIP                                       AccredAgency  \
# 0     AL       35762  Southern Association of Colleges and Schools C...
# 1     AL  35294-0110  Southern Association of Colleges and Schools C...
# 2     AL  36117-3553  Southern Association of Colleges and Schools C...
#
#                      INSTURL  \
# 0              www.aamu.edu/
# 1                www.uab.edu
# 2  www.amridgeuniversity.edu
#
#                                               NPCURL  ...  \
# 0     galileo.aamu.edu/netpricecalculator/npcalc.htm  ...
# 1    www.collegeportraits.org/AL/UAB/estimator/agree  ...
# 2  tcc.noellevitz.com/(S(miwoihs5stz5cpyifh4nczu0...  ...
#
# ...

# %%
print(len(df_2011_1))
print(len(df_2011_2))
print(len(df_2012_1))
print(len(df_2012_2))
print(len(df_2013))
# Out:
# 3797
# 3878
# 3797
# 3996
# 7804

# %%
frames = [df_2011_1, df_2011_2, df_2012_1, df_2012_2, df_2013]
pd.concat(frames)
# Out:
#         UNITID    OPEID  opeid6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7799  48285703   157107    1571
# 7800  48285704   157101    1571
# 7801  48285705   157105    1571
# 7802  48285706   157100    1571
# 7803  48285707   157103    1571
#
#                                              INSTNM            CITY STABBR  \
# 0                          Alabama A & M University          Normal     AL
# 1               University of Alabama at Birmingham      Birmingham     AL
# 2                                Amridge University      Montgomery     AL
# 3               University of Alabama at Huntsville      Huntsville     AL
# 4                          Alabama State University      Montgomery     AL
# ...                                             ...             ...    ...
# ...

# %%
len(df_2011_1)+len(df_2011_2)+len(df_2012_1)+len(df_2012_2)+len(df_2013)
# Out:
# 23272

# %%
pd.concat(frames, keys=['2011', '2011', '2012', '2012', '2013'])
# Out:
#              UNITID    OPEID  opeid6  \
# 2011 0       100654   100200    1002
#      1       100663   105200    1052
#      2       100690  2503400   25034
#      3       100706   105500    1055
#      4       100724   100500    1005
# ...             ...      ...     ...
# 2013 7799  48285703   157107    1571
#      7800  48285704   157101    1571
#      7801  48285705   157105    1571
#      7802  48285706   157100    1571
#      7803  48285707   157103    1571
#
#                                                   INSTNM            CITY  \
# 2011 0                          Alabama A & M University          Normal
#      1               University of Alabama at Birmingham      Birmingham
#      2                                Amridge University      Montgomery
#      3               University of Alabama at Huntsville      Huntsville
#      4                          Alabama State University      Montgomery
# ...
